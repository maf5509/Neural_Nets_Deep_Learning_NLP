# %%
import nltk
from nltk.corpus import gutenberg
nltk.download('gutenberg')
nltk.download('punkt')
import re
import pandas as pd
from sklearn.model_selection import train_test_split

#reading in the data, this time in the form of paragraphs
emma=gutenberg.paras('austen-emma.txt')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\fergu\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\fergu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
words = ['a','very','few','minutes','more','however','completed','the','present','trial']

# %%
# Where does the '--' appear?
indices = []
for i in range(0, len(emma)):
    for j in range(0, len(emma[i])):
        if '--' in (emma[i][j]):
            indices.append((i,j))
len(indices)
# Out:
# 963

# %%
emma[469200:470900]
# Out:
# 'st natural to pay your visit, then"--\n\nHe was silent.  She believed he was looking at her; probably reflecting\non what she had said, and trying to understand the manner.\nShe heard him sigh.  It was natural for him to feel that he had\n_cause_ to sigh.  He could not believe her to be encouraging him.\nA few awkward moments passed, and he sat down again; and in a more\ndetermined manner said,\n\n"It was something to feel that all the rest of my time might be\ngiven to Hartfield.  My regard for Hartfield is most warm"--\n\nHe stopt again, rose again, and seemed quite embarrassed.--\nHe was more in love with her than Emma had supposed; and who can say\nhow it might have ended, if his father had not made his appearance?\nMr. Woodhouse soon followed; and the necessity of exertion made\nhim composed.\n\nA very few minutes more, however, completed the present trial.\nMr. Weston, always alert when business was to be done, and as\nincapable of procrastinating any evil that was inevitable,\nas of foreseeing any that was doubtful, said, "It was time to go;"\nand the young man, though he might and did sigh, could not but agree,\nto take leave.\n\n"I shall hear about you all," said he; "that is my chief consolation.\nI shall hear of every thing that is going on among you.  I have\nengaged Mrs. Weston to correspond with me.  She has been so kind as\nto promise it.  Oh! the blessing of a female correspondent, when one\nis really interested in the absent!--she will tell me every thing.\nIn her letters I shall be at dear Highbury again."\n\nA very friendly shake of the hand, a very earnest "Good-bye,"\nclosed the speech, and the door had soon shut out Frank Churchill.\nShort had been the notice--short their meeting; he'

# %%
#processing
emma_paras=[]
for paragraph in emma:
    para=paragraph[0]
    #removing the double-dash from all words
    para=[re.sub(r'--','',word) for word in para]
    #Forming each paragraph into a string and adding it to the list of strings.
    emma_paras.append(' '.join(para))

print(emma_paras[0:4])
# Out:
# ['[ Emma by Jane Austen 1816 ]', 'VOLUME I', 'CHAPTER I', 'Emma Woodhouse , handsome , clever , and rich , with a comfortable home and happy disposition , seemed to unite some of the best blessings of existence ; and had lived nearly twenty - one years in the world with very little to distress or vex her .']

# %%
indices = []
for i in range(0, len(emma)):
    for j in range(0, len(emma[i])):
        if '--' in (emma[i][j]):
            indices.append((i,j))
len(indices)
# Out:
# 963

# %%
print(emma_paras[10])
# Out:
# The evil of the actual disparity in their ages ( and Mr . Woodhouse had not married early ) was much increased by his constitution and habits ; for having been a valetudinarian all his life , without activity of mind or body , he was a much older man in ways than in years ; and though everywhere beloved for the friendliness of his heart and his amiable temper , his talents could not have recommended him at any time .

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

X_train, X_test = train_test_split(emma_paras, test_size=0.4, random_state=0)

vectorizer = TfidfVectorizer(max_df=0.5, # drop words that occur in more than half the paragraphs
                             min_df=2, # only use words that appear at least twice
                             stop_words='english', 
                             lowercase=True, #convert everything to lower case (since Alice in Wonderland has the HABIT of CAPITALIZING WORDS for EMPHASIS)
                             use_idf=True,#we definitely want to use inverse document frequencies in our weighting
                             norm=u'l2', #Applies a correction factor so that longer paragraphs and shorter paragraphs get treated equally
                             smooth_idf=True #Adds 1 to all document frequencies, as if an extra document existed that used every word once.  Prevents divide-by-zero errors
                            )


#Applying the vectorizer
emma_paras_tfidf=vectorizer.fit_transform(emma_paras)
print("Number of features: %d" % emma_paras_tfidf.get_shape()[1])
# Out:
# Number of features: 1948

# %%
emma_paras_tfidf
# Out:
# <2371x1948 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16742 stored elements in Compressed Sparse Row format>

# %%
emma_paras_tfidf.shape
# Out:
# (2371, 1948)

# %%
emma_paras_tfidf[3]
# Out:
# <1x1948 sparse matrix of type '<class 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>

# %%
#splitting into training and test sets
X_train_tfidf, X_test_tfidf= train_test_split(emma_paras_tfidf, test_size=0.4, random_state=0)

#Reshapes the vectorizer output into something people can read
X_train_tfidf_csr = X_train_tfidf.tocsr()

#number of paragraphs
n = X_train_tfidf_csr.shape[0]
#A list of dictionaries, one per paragraph
tfidf_bypara = [{} for _ in range(0,n)]
#List of features
terms = vectorizer.get_feature_names()
#for each paragraph, lists the feature words and their tf-idf scores
for i, j in zip(*X_train_tfidf_csr.nonzero()):
    tfidf_bypara[i][terms[j]] = X_train_tfidf_csr[i, j ]

#Keep in mind that the log base 2 of 1 is 0, so a tf-idf score of 0 indicates that the word was present once in that sentence.
print('Original sentence:', X_train[9])
print('Tf_idf vector:', tfidf_bypara[9])
# Out:
# Original sentence: " There appeared such a perfectly good understanding among them all " he began rather quickly , but checking himself , added , " however , it is impossible for me to say on what terms they really were  how it might all be behind the scenes .
# Tf_idf vector: {'quickly': 0.38070256670926012, 'appeared': 0.31256680566382117, 'impossible': 0.31612334890976324, 'perfectly': 0.30038109873611568, 'added': 0.30316823321090014, 'terms': 0.36919964367970953, 'understanding': 0.31612334890976324, 'good': 0.2174154906397317, 'began': 0.28226673772842847, 'say': 0.21851232841598259, 'really': 0.25369233488450216}

# %%
stop = list(stopwords.words('english'))

# %%
len(terms)
# Out:
# 1948

# %%
terms
# Out:
# ['_has_',
#  '_her_',
#  '_him_',
#  '_home_',
#  '_i_',
#  '_is_',
#  '_me_',
#  '_my_',
#  '_not_',
#  '_one_',
#  '_she_',
#  '_that_',
#  '_then_',
#  '_very_',
#  '_we_',
#  '_you_',
#  'abbey',
#  'able',
#  'abroad',
#  'absence',
#  'absent',
#  'absolutely',
#  'accept',
#  'acceptable',
#  'accepted',
#  'accepting',
#  'accompanied',
#  'accomplished',
#  'account',
#  'acknowledge',
#  'acknowledged',
#  'acquaintance',
#  'acquainted',
#  'acquiescence',
#  'acquirements',
#  'act',
#  'acting',
#  'activity',
#  'actually',
#  'added',
#  'address',
#  'addressed',
#  'addressing',
#  'admiration',
#  'admire',
#  'admired',
#  'admit',
#  'admitted',
#  'advanced',
#  'advantage',
#  'advantages',
#  'adventure',
#  'advice',
#  'advise',
#  'advised',
#  'affair',
#  'affected',
#  'affection',
#  'affectionate',
#  'afford',
#  'afforded',
#  'affronted',
#  'afraid',
#  'afternoon',
#  'age',
#  'agitated',
#  'agitation',
#  'ago',
#  'agree',
#  'agreeable',
#  'agreed',
#  'ah',
#  'aimed',
#  'air',
#  'alarm',
#  'alarming',
#  'alertness',
#  'alike',
#  'alleviation',
#  'alliance',
#  'allow',
#  'allowed',
#  'allowing',
#  'alloy',
#  'allusion',
#  'aloud',
#  'alphabets',
#  'altogether',
#  'amiable',
#  'amiss',
#  'ample',
#  'amused',
#  'amusement',
#  'anger',
#  'angry',
#  'anne',
#  'announce',
#  'announced',
#  'answer',
#  'answered',
#  'answering',
#  'anxiety',
#  'anxious',
#  'anxiously',
#  'apologies',
#  'apparent',
#  'apparently',
#  'appeal',
#  'appear',
#  'appearance',
#  'appeared',
#  'appearing',
#  'appears',
#  'apple',
#  'apprehensive',
#  'approach',
#  'approaching',
#  'approbation',
#  'approval',
#  'approve',
#  'approved',
#  'april',
#  'arch',
#  'ardent',
#  'argument',
#  'arise',
#  'arm',
#  'arose',
#  'arrange',
#  'arranged',
#  'arrangement',
#  'arrival',
#  'arrive',
#  'arrived',
#  'ashamed',
#  'ask',
#  'asked',
#  'asking',
#  'assembled',
#  'assent',
#  'assist',
#  'assistance',
#  'assisted',
#  'assurance',
#  'assurances',
#  'assure',
#  'assured',
#  'assuring',
#  'astonished',
#  'attached',
#  'attachment',
#  'attempt',
#  'attempted',
#  'attempts',
#  'attend',
#  'attended',
#  'attending',
#  'attention',
#  'attentions',
#  'attentive',
#  'attitude',
#  'aunt',
#  'autumn',
#  'averting',
#  'avoid',
#  'avoiding',
#  'aware',
#  'away',
#  'awkward',
#  'aye',
#  'bad',
#  'ball',
#  'basin',
#  'bates',
#  'bath',
#  'bathing',
#  'beam',
#  'bear',
#  'bears',
#  'beautiful',
#  'beautifully',
#  'beauty',
#  'bed',
#  'beg',
#  'began',
#  'begged',
#  'begin',
#  'beginning',
#  'begun',
#  'behaved',
#  'behaviour',
#  'behold',
#  'believe',
#  'believed',
#  'believing',
#  'bell',
#  'belong',
#  'belonged',
#  'beloved',
#  'best',
#  'betray',
#  'better',
#  'bickerton',
#  'birth',
#  'blessing',
#  'blessings',
#  'blinded',
#  'blunder',
#  'blush',
#  'blushed',
#  'blushing',
#  'body',
#  'book',
#  'boot',
#  'bore',
#  'born',
#  'borne',
#  'bow',
#  'bowed',
#  'box',
#  'boy',
#  'boys',
#  'brain',
#  'break',
#  'breakfast',
#  'breaking',
#  'bride',
#  'brilliant',
#  'bring',
#  'bringing',
#  'brings',
#  'broad',
#  'brother',
#  'brought',
#  'burn',
#  'burst',
#  'business',
#  'bustle',
#  'busy',
#  'bye',
#  'cake',
#  'called',
#  'calling',
#  'calmness',
#  'came',
#  'campbell',
#  'campbells',
#  'capable',
#  'captain',
#  'card',
#  'cards',
#  'care',
#  'cared',
#  'careless',
#  'cares',
#  'carriage',
#  'carriages',
#  'carried',
#  'carrying',
#  'case',
#  'catch',
#  'caught',
#  'cause',
#  'caution',
#  'cease',
#  'ceremony',
#  'certain',
#  'certainly',
#  'certainty',
#  'chair',
#  'chance',
#  'chances',
#  'change',
#  'changed',
#  'chapter',
#  'character',
#  'charade',
#  'charge',
#  'charitable',
#  'charity',
#  'charm',
#  'charming',
#  'charmingly',
#  'checked',
#  'cheeks',
#  'cheerful',
#  'cheerfully',
#  'chiefly',
#  'child',
#  'children',
#  'choice',
#  'chose',
#  'chosen',
#  'christmas',
#  'church',
#  'churchill',
#  'churchills',
#  'chuse',
#  'circumstance',
#  'circumstances',
#  'civil',
#  'civilities',
#  'civilly',
#  'claim',
#  'claims',
#  'class',
#  'cleared',
#  'clever',
#  'clock',
#  'close',
#  'closed',
#  'coachman',
#  'cold',
#  'coldness',
#  'cole',
#  'coles',
#  'collect',
#  'collected',
#  'colonel',
#  'colour',
#  'come',
#  'comes',
#  'comfort',
#  'comfortable',
#  'comfortably',
#  'comforted',
#  'coming',
#  'command',
#  'common',
#  'communicated',
#  'communication',
#  'communicative',
#  'companion',
#  'companions',
#  'company',
#  'compare',
#  'compared',
#  'comparison',
#  'compassion',
#  'complacency',
#  'complaint',
#  'complete',
#  'completely',
#  'complexion',
#  'compliment',
#  'compliments',
#  'compose',
#  'composure',
#  'comprehend',
#  'concealed',
#  'concealment',
#  'concern',
#  'concerned',
#  'concerns',
#  'conclude',
#  'concluding',
#  'conclusion',
#  'concurrence',
#  'conduct',
#  'confess',
#  'confession',
#  'confidence',
#  'confined',
#  'confirmed',
#  'confused',
#  'confusion',
#  'congratulated',
#  'conjectures',
#  'connected',
#  'connexion',
#  'connexions',
#  'conscience',
#  'conscious',
#  'consciousness',
#  'consent',
#  'consequence',
#  'consider',
#  'considerable',
#  'consideration',
#  'considered',
#  'considering',
#  'consolation',
#  'constitution',
#  'consulted',
#  'containing',
#  'contented',
#  'continue',
#  'continued',
#  'continuing',
#  'contradict',
#  'contradiction',
#  'contrive',
#  'contrived',
#  'convenience',
#  'conversation',
#  'conveyed',
#  'conviction',
#  'convince',
#  'convinced',
#  'convincing',
#  'cool',
#  'cooler',
#  'coolly',
#  'cordial',
#  'cordially',
#  'correct',
#  'cottage',
#  'countenance',
#  'counteract',
#  'country',
#  'couple',
#  'course',
#  'court',
#  'cox',
#  'creating',
#  'creature',
#  'credit',
#  'cried',
#  'cross',
#  'crossed',
#  'crown',
#  'curiosity',
#  'cut',
#  'daily',
#  'dance',
#  'danced',
#  'dances',
#  'dancing',
#  'danger',
#  'dare',
#  'dared',
#  'darted',
#  'daughter',
#  'daughters',
#  'day',
#  'days',
#  'deal',
#  'dear',
#  'dearest',
#  'deceived',
#  'december',
#  'decided',
#  'decidedly',
#  'decision',
#  'decisive',
#  'declaration',
#  'declare',
#  'declared',
#  'declares',
#  'declined',
#  'declining',
#  'deep',
#  'deeply',
#  'deficiency',
#  'deficient',
#  'degree',
#  'delay',
#  'delays',
#  'delicacy',
#  'delicate',
#  'delight',
#  'delighted',
#  'delightful',
#  'deny',
#  'denying',
#  'depend',
#  'depended',
#  'dependence',
#  'depressed',
#  'deserve',
#  'deserved',
#  'desirable',
#  'desired',
#  'desiring',
#  'destiny',
#  'detained',
#  'determined',
#  'device',
#  'did',
#  'die',
#  'difference',
#  'different',
#  'differently',
#  'difficulties',
#  'difficulty',
#  'dignity',
#  'dine',
#  'dined',
#  'dinner',
#  'direct',
#  'directions',
#  'directly',
#  'dirty',
#  'disagreeable',
#  'disappointed',
#  'disappointment',
#  'discoveries',
#  'discovery',
#  'disengaged',
#  'dislike',
#  'disparity',
#  'displays',
#  'displeasure',
#  'disposed',
#  'disposition',
#  'dissuade',
#  'distance',
#  'distant',
#  'distinct',
#  'distinction',
#  'distinctly',
#  'distress',
#  'distressing',
#  'distrust',
#  'divided',
#  'divisions',
#  'dixon',
#  'dixons',
#  'does',
#  'doing',
#  'domestic',
#  'don',
#  'donwell',
#  'door',
#  'doors',
#  'doubt',
#  'doubtful',
#  'doubts',
#  'downright',
#  'downstairs',
#  'drawing',
#  'drawn',
#  'dreadful',
#  'dream',
#  'drive',
#  'driving',
#  'dulness',
#  'duty',
#  'dwell',
#  'eager',
#  'eagerly',
#  'eagerness',
#  'earlier',
#  'early',
#  'earnest',
#  'earnestly',
#  'earth',
#  'ease',
#  'easily',
#  'easy',
#  'eat',
#  'education',
#  'effect',
#  'effort',
#  'elder',
#  'eldest',
#  'elegance',
#  'elegancies',
#  'elegant',
#  'elton',
#  'eltons',
#  'emma',
#  'employ',
#  'employed',
#  'employment',
#  'encouraged',
#  'encouragement',
#  'encumbrance',
#  'end',
#  'endeavour',
#  'ended',
#  'endure',
#  'engaged',
#  'engagement',
#  'engagements',
#  'engaging',
#  'enjoy',
#  'enjoying',
#  'enjoyment',
#  'enscombe',
#  'enter',
#  'entered',
#  'entering',
#  'entertain',
#  'entertainment',
#  'entire',
#  'entirely',
#  'entrance',
#  'entreat',
#  'entreaties',
#  'envy',
#  'equal',
#  'equally',
#  'error',
#  'escape',
#  'escaped',
#  'escorted',
#  'especially',
#  'established',
#  'establishment',
#  'estate',
#  'evening',
#  'event',
#  'evident',
#  'evidently',
#  'evil',
#  'evils',
#  'exact',
#  'exactly',
#  'examining',
#  'example',
#  'exceed',
#  'exceedingly',
#  'excellent',
#  'exception',
#  'excited',
#  'exciting',
#  'exclaim',
#  'exclaimed',
#  'excuse',
#  'excuses',
#  'exercise',
#  'exertion',
#  'exertions',
#  'existence',
#  'expect',
#  'expectation',
#  'expected',
#  'expecting',
#  'experience',
#  'expert',
#  'explanation',
#  'explanations',
#  'express',
#  'expressed',
#  'expression',
#  'expressions',
#  'expressive',
#  'exquisite',
#  'extraordinary',
#  'extreme',
#  'extremely',
#  'exultation',
#  'eye',
#  'eyes',
#  'face',
#  'fact',
#  'fail',
#  'failed',
#  'fair',
#  'fairfax',
#  'fairly',
#  'fall',
#  'fallen',
#  'falling',
#  'family',
#  'fancied',
#  'fanciful',
#  'fancy',
#  'fancying',
#  'far',
#  'farm',
#  'farmer',
#  'farther',
#  'fast',
#  'fate',
#  'father',
#  'fatigued',
#  'fault',
#  'faults',
#  'favour',
#  'favourable',
#  'favourite',
#  'fear',
#  'fearful',
#  'fears',
#  'features',
#  'feel',
#  'feeling',
#  'feelingly',
#  'feelings',
#  'feels',
#  'fell',
#  'fellow',
#  'felt',
#  'fewer',
#  'finding',
#  'fine',
#  'finish',
#  'finished',
#  'fit',
#  'fix',
#  'fixed',
#  'flatter',
#  'flow',
#  'flutter',
#  'follow',
#  'followed',
#  'following',
#  'fond',
#  'fondly',
#  'foolish',
#  'foot',
#  'footpath',
#  'force',
#  'forced',
#  'ford',
#  'foreseen',
#  'forget',
#  'forgetting',
#  'forgive',
#  'forgiven',
#  'forgotten',
#  'form',
#  'formed',
#  'forming',
#  'fortnight',
#  'fortunate',
#  'fortune',
#  'forward',
#  'foundation',
#  'framed',
#  'frank',
#  'free',
#  'frequent',
#  'fresh',
#  'friend',
#  'friendly',
#  'friends',
#  'friendship',
#  'frightened',
#  'frozen',
#  'fully',
#  'future',
#  'gallant',
#  'gallantry',
#  'garden',
#  'gardens',
#  'gate',
#  'gates',
#  'gave',
#  'gay',
#  'general',
#  'generally',
#  'genteel',
#  'gentility',
#  'gentle',
#  'gentleman',
#  'gentlemen',
#  'george',
#  'getting',
#  'gilbert',
#  'gipsies',
#  'girl',
#  'girls',
#  'given',
#  'gives',
#  'giving',
#  'glad',
#  'glance',
#  'glancing',
#  'glow',
#  'god',
#  'goddard',
#  'going',
#  'gone',
#  'good',
#  'goodness',
#  'goodwill',
#  'got',
#  'governess',
#  'grace',
#  'graceful',
#  'graciously',
#  'gradually',
#  'grand',
#  'grant',
#  'granted',
#  'grateful',
#  'gratified',
#  'gratitude',
#  'grave',
#  'gravely',
#  'great',
#  'greater',
#  'greatest',
#  'grew',
#  'ground',
#  'grounds',
#  'grove',
#  'grow',
#  'growing',
#  'grown',
#  'gruel',
#  'guard',
#  'guess',
#  'guessed',
#  'guessing',
#  'guests',
#  'guided',
#  'guilt',
#  'habit',
#  'habits',
#  'hair',
#  'half',
#  'hand',
#  'hands',
#  'handsome',
#  'handsomely',
#  'handwriting',
#  'happen',
#  'happened',
#  'happier',
#  'happiest',
#  'happily',
#  'happiness',
#  'happy',
#  'hard',
#  'hardly',
#  'harm',
#  'harriet',
#  'hartfield',
#  'hastily',
#  'having',
#  'hawkins',
#  'hazle',
#  'head',
#  'heal',
#  'health',
#  'hear',
#  'heard',
#  'hearing',
#  'heart',
#  'hearted',
#  'heavy',
#  'heir',
#  'help',
#  'helped',
#  'henry',
#  'hesitated',
#  'hesitating',
#  'hesitatingly',
#  'hesitation',
#  'high',
#  'highbury',
#  'highest',
#  'highly',
#  'hill',
#  'hint',
#  'hints',
#  'history',
#  'hitherto',
#  'hold',
#  'home',
#  'honest',
#  'honour',
#  'honoured',
#  'hope',
#  'hoped',
#  'hopes',
#  'hoping',
#  'horror',
#  'horse',
#  'horseback',
#  'horses',
#  'hot',
#  'hour',
#  'hours',
#  'house',
#  'housekeeper',
#  'houses',
#  'human',
#  'humble',
#  'humour',
#  'humph',
#  'hurried',
#  'hurry',
#  'hurrying',
#  'hurt',
#  'husband',
#  'idea',
#  'ideas',
#  'idle',
#  'ignorance',
#  'ignorant',
#  'ii',
#  'iii',
#  'ill',
#  'imagination',
#  'imagine',
#  'imagined',
#  'immediate',
#  'immediately',
#  'impatience',
#  'importance',
#  'important',
#  'impossible',
#  'impressed',
#  'impression',
#  'improved',
#  'improvement',
#  'inclination',
#  'inclined',
#  'incommoded',
#  'increase',
#  'increased',
#  'increasing',
#  'independence',
#  'independent',
#  'indifference',
#  'indifferent',
#  'indignation',
#  'induced',
#  'indulge',
#  'indulgence',
#  'indulgent',
#  'inferior',
#  'inferred',
#  'influence',
#  'information',
#  'ingenious',
#  'inimitable',
#  'injustice',
#  'inquire',
#  'inquiry',
#  'insensible',
#  'insincere',
#  'instance',
#  'instant',
#  'instantly',
#  'instead',
#  'instrument',
#  'insufferable',
#  'intellects',
#  'intelligence',
#  'intelligible',
#  'intended',
#  'intent',
#  'intention',
#  'intentions',
#  'interested',
#  'interesting',
#  'interrupted',
#  'intimacy',
#  'intimate',
#  'introduce',
#  'introduced',
#  'introducing',
#  'introduction',
#  'invitation',
#  'invitations',
#  'invite',
#  'invited',
#  'ireland',
#  'irregular',
#  'isabella',
#  'iv',
#  'ix',
#  'james',
#  'jane',
#  'john',
#  'join',
#  'joined',
#  'journey',
#  'joy',
#  'joyous',
#  'judge',
#  'judging',
#  'judgment',
#  'june',
#  'just',
#  'justice',
#  'justified',
#  'keeping',
#  'kept',
#  'kind',
#  'kindly',
#  'kindness',
#  'kings',
#  'kissed',
#  'kitty',
#  'knew',
#  'knightley',
#  'knightleys',
#  'know',
#  'knowing',
#  'knowledge',
#  'known',
#  'knows',
#  'lace',
#  'ladies',
#  'lady',
#  'laid',
#  'lame',
#  'lament',
#  'lane',
#  'language',
#  'large',
#  'larger',
#  'larkins',
#  ...]

# %%
X_train_tfidf.shape
# Out:
# (1422, 1948)

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
import pandas as pd

#Our SVD data reducer.  We are going to reduce the feature space from 1379 to 130.
svd= TruncatedSVD(130)
lsa = make_pipeline(svd, Normalizer(copy=False))
# Run SVD on the training data, then project the training data.
X_train_lsa = lsa.fit_transform(X_train_tfidf)

variance_explained=svd.explained_variance_ratio_
total_variance = variance_explained.sum()
print("Percent variance captured by all components:",total_variance*100)

#Looking at what sorts of paragraphs our solution considers similar, for the first five identified topics
paras_by_component=pd.DataFrame(X_train_lsa,index=X_train)
for i in range(5):
    print('Component {}:'.format(i))
    print(paras_by_component.loc[:,i].sort_values(ascending=False)[0:10])
# Out:
# Percent variance captured by all components: 45.2237796232
# Component 0:
# " Oh !    0.999289
# " Oh !    0.999289
# " Oh !    0.999289
# " Oh !    0.999289
# " Oh !    0.999289
# " Oh !    0.999289
# " Oh !    0.999289
# " Oh !    0.999289
# " Oh !    0.999289
# " Oh !    0.999289
# Name: 0, dtype: float64
# Component 1:
# " You have made her too tall , Emma ," said Mr . Knightley .                                                                                                                0.634392
# " You get upon delicate subjects , Emma ," said Mrs . Weston smiling ; " remember that I am here . Mr .                                                                     0.589447
# " You are right , Mrs . Weston ," said Mr . Knightley warmly , " Miss Fairfax is as capable as any of us of forming a just opinion of Mrs . Elton .                         0.567127
# " I do not know what your opinion may be , Mrs . Weston ," said Mr . Knightley , " of this great intimacy between Emma and Harriet Smith , but I think it a bad thing ."    0.563946
# " There were misunderstandings between them , Emma ; he said so expressly .                                                                                                 0.528900
# Mr . Knightley might quarrel with her , but Emma could not quarrel with herself .                                                                                           0.525053
# Emma found that it was not Mr . Weston ' s fault that the number of privy councillors was not yet larger .                                                                  0.508868
# " In one respect , perhaps , Mr . Elton ' s manners are superior to Mr . Knightley ' s or Mr . Weston ' s .                                                                 0.506647
# " Now ," said Emma , when they were fairly beyond the sweep gates , " now Mr . Weston , do let me know what has happened ."                                                 0.503611
# " Emma ," said Mr . Knightley presently , " I have a piece of news for you .                                                                                                0.500126
# Name: 1, dtype: float64
# Component 2:
# CHAPTER I       0.998642
# CHAPTER V       0.998642
# CHAPTER I       0.998642
# CHAPTER X       0.998642
# CHAPTER X       0.998642
# CHAPTER V       0.998642
# CHAPTER V       0.998642
# CHAPTER X       0.998642
# CHAPTER I       0.998642
# CHAPTER XIII    0.997593
# Name: 2, dtype: float64
# Component 3:
# " Ah !     0.99291
# " Ah !     0.99291
# " Ah !     0.99291
# " Ah !"    0.99291
# " Ah !     0.99291
# " Ah !     0.99291
# " Ah !     0.99291
# " Ah !     0.99291
# " Ah !     0.99291
# " Ah !     0.99291
# Name: 3, dtype: float64
# Component 4:
# " There were misunderstandings between them , Emma ; he said so expressly .    0.651264
# Emma demurred .                                                                0.598797
# " Are you well , my Emma ?"                                                    0.598797
# Emma was silenced .                                                            0.587979
# At first it was downright dulness to Emma .                                    0.586727
# " Emma , my dear Emma "                                                        0.577051
# Emma could not resist .                                                        0.568584
# " It is not now worth a regret ," said Emma .                                  0.561348
# " For shame , Emma !                                                           0.551813
# " I am ready ," said Emma , " whenever I am wanted ."                          0.517163
# Name: 4, dtype: float64

# %%
paras_by_component.head(2)
# Out:
#                                                          0         1    \
# That is _court_ .                                   0.391944 -0.509545
# " Yes , sir , I did indeed ; and I am very much...  0.014070  0.125261
#
#                                                              2         3    \
# That is _court_ .                                   3.053580e-02 -0.011556
# " Yes , sir , I did indeed ; and I am very much...  4.132881e-07  0.003231
#
#                                                          4         5    \
# That is _court_ .                                   0.254937  0.024881
# " Yes , sir , I did indeed ; and I am very much...  0.041845  0.039685
#
#                                                          6         7    \
# That is _court_ .                                  -0.088924 -0.206576
# " Yes , sir , I did indeed ; and I am very much... -0.034034  0.127426
#
#                                                          8         9    \
# That is _court_ .                                   0.244483 -0.258231
# " Yes , sir , I did indeed ; and I am very much...  0.190266 -0.006022
#
#                                                       ...          120  \
# That is _court_ .                                     ...    -0.057597
# " Yes , sir , I did indeed ; and I am very much...    ...    -0.035948
#
#                                                          121       122  \
# That is _court_ .                                   0.003398  0.042977
# " Yes , sir , I did indeed ; and I am very much...  0.051358 -0.075620
#
#                                                          123       124  \
# That is _court_ .                                   0.024329 -0.013637
# " Yes , sir , I did indeed ; and I am very much...  0.010487  0.028900
#
#                                                          125       126  \
# That is _court_ .                                  -0.031724  0.003121
# " Yes , sir , I did indeed ; and I am very much...  0.019664  0.007657
#
#                                                          127       128  \
# That is _court_ .                                   0.092914  0.056200
# " Yes , sir , I did indeed ; and I am very much... -0.018987 -0.036149
#
#                                                          129
# That is _court_ .                                  -0.046291
# " Yes , sir , I did indeed ; and I am very much... -0.039627
#
# [2 rows x 130 columns]

# %% [markdown]
# ### Applying the Model to the Test Set
# Here we see the following: <BR/><BR/>
# Component 0: Similar to training set<BR/>
# Component 1: Similar to training set<BR/>
# Component 2: Similar to Component 3 of training set<BR/>
# Component 3: Similar to Component 1<BR/>
# Component 4: A collection of responses in the affirmative. Not similar to any of  Components 0-4 of training set. Possibly similar to another component of training set.

# %%
# Run SVD on the training data, then project the training data.
X_test_lsa = lsa.fit_transform(X_test_tfidf)

variance_explained=svd.explained_variance_ratio_
total_variance = variance_explained.sum()
print("Percent variance captured by all components:",total_variance*100)

#Looking at what sorts of paragraphs our solution considers similar, for the first five identified topics
paras_by_component=pd.DataFrame(X_test_lsa,index=X_test)
for i in range(5):
    print('Component {}:'.format(i))
    print(paras_by_component.loc[:,i].sort_values(ascending=False)[0:10])
# Out:
# Percent variance captured by all components: 49.3509674668
# Component 0:
# " Oh !       0.99992
# " Oh !       0.99992
# " Oh no !    0.99992
# " Oh !       0.99992
# " Oh !       0.99992
# " Oh !       0.99992
# " Oh !       0.99992
# " Oh !       0.99992
# " Oh !"      0.99992
# " Oh !       0.99992
# Name: 0, dtype: float64
# Component 1:
# " Well , Mrs . Weston ," said Emma triumphantly when he left them , " what do you say now to Mr . Knightley ' s marrying Jane Fairfax ?"                                                                                                                                                                                                                                                                                                             0.617004
# After tea , Mr . and Mrs . Weston , and Mr . Elton sat down with Mr . Woodhouse to cards .                                                                                                                                                                                                                                                                                                                                                           0.599272
# Frank turned instantly to Emma , to claim her former promise ; and boasted himself an engaged man , which his father looked his most perfect approbation of  and it then appeared that Mrs . Weston was wanting _him_ to dance with Mrs . Elton himself , and that their business was to help to persuade him into it , which was done pretty soon . Mr . Weston and Mrs . Elton led the way , Mr . Frank Churchill and Miss Woodhouse followed .    0.570680
# " Mr .                                                                                                                                                                                                                                                                                                                                                                                                                                               0.520882
# While she was gone , Mr . Knightley called , and sat some time with Mr . Woodhouse and Emma , till Mr . Woodhouse , who had previously made up his mind to walk out , was persuaded by his daughter not to defer it , and was induced by the entreaties of both , though against the scruples of his own civility , to leave Mr . Knightley for that purpose .                                                                                       0.511264
# Mr . Weston was musing .                                                                                                                                                                                                                                                                                                                                                                                                                             0.505365
# " I think , indeed ," said John Knightley pleasantly , " that Mr . Weston has some little claim .                                                                                                                                                                                                                                                                                                                                                    0.492429
# " Mrs . Weston ' s manners ," said Emma , " were always particularly good .                                                                                                                                                                                                                                                                                                                                                                          0.492148
# " It is Frank and Miss Fairfax ," said Mrs . Weston .                                                                                                                                                                                                                                                                                                                                                                                                0.485555
# " Why , to be sure ," said Mr . Woodhouse " yes , certainly  I cannot deny that Mrs . Weston , poor Mrs . Weston , does come and see us pretty often  but then  she is always obliged to go away again ."                                                                                                                                                                                                                                            0.484044
# Name: 1, dtype: float64
# Component 2:
# " Ah !     0.99697
# " Ah !     0.99697
# " Ah !     0.99697
# " Ah !     0.99697
# " Ah !     0.99697
# " Ah !"    0.99697
# " Ah !     0.99697
# " Ah !     0.99697
# " Ah !     0.99697
# " Ah !"    0.99697
# Name: 2, dtype: float64
# Component 3:
# " Mr .                                                                                                                                                                                                                                                                                                                                                            0.635591
# After tea , Mr . and Mrs . Weston , and Mr . Elton sat down with Mr . Woodhouse to cards .                                                                                                                                                                                                                                                                        0.563473
# Mr . Knightley was thoughtful again .                                                                                                                                                                                                                                                                                                                             0.525628
# " You are not vain , Mr . Knightley .                                                                                                                                                                                                                                                                                                                             0.510240
# Mr . Weston was musing .                                                                                                                                                                                                                                                                                                                                          0.499972
# Mr . Weston ' s own happiness was indisputable .                                                                                                                                                                                                                                                                                                                  0.455686
# She meant to be very happy , in spite of the scene being laid at Mr . Cole ' s ; and without being able to forget that among the failings of Mr . Elton , even in the days of his favour , none had disturbed her more than his propensity to dine with Mr . Cole .                                                                                               0.414556
# Harriet , Mr . Elton , and Mr . Knightley , their own especial set , were the only persons invited to meet them ; the hours were to be early , as well as the numbers few ; Mr . Woodhouse ' s habits and inclination being consulted in every thing .                                                                                                            0.403160
# While she was gone , Mr . Knightley called , and sat some time with Mr . Woodhouse and Emma , till Mr . Woodhouse , who had previously made up his mind to walk out , was persuaded by his daughter not to defer it , and was induced by the entreaties of both , though against the scruples of his own civility , to leave Mr . Knightley for that purpose .    0.389877
# " Christmas weather ," observed Mr . Elton .                                                                                                                                                                                                                                                                                                                      0.389820
# Name: 3, dtype: float64
# Component 4:
# " Yes , sometimes he can ."                                                     0.653238
# " Yes .                                                                         0.653238
# " Yes , do ."                                                                   0.653238
# " Yes I should , I am sure I should .                                           0.638911
# " Yes , so I imagined .                                                         0.606280
# " Yes  a good deal _nearer_ ."                                                  0.559472
# " Yes , our good Mrs . Elton .                                                  0.553650
# " Yes ; but we must not rest our claims on that distinction .                   0.545886
# " Yes , very soon .                                                             0.533736
# " Yes , she would be , but that she thinks there will be another put - off .    0.525643
# Name: 4, dtype: float64

# %% [markdown]
# ### Tweaking tf-idf

# %% [markdown]
# #### 1. Change norm to None<BR/>
# Comparing to the training set in the first example (norm=u'l2'). i.e. longer and shorter paragraphs do NOT get treated equally: <BR/><BR/>
# This results in descending sentence lengths as you go through the component.

# %%
vectorizer = TfidfVectorizer(max_df=0.5, # drop words that occur in more than half the paragraphs
                             min_df=2, # only use words that appear at least twice
                             stop_words='english', 
                             lowercase=True, #convert everything to lower case (since Alice in Wonderland has the HABIT of CAPITALIZING WORDS for EMPHASIS)
                             use_idf=True,#we definitely want to use inverse document frequencies in our weighting
                             norm=None, #if used, would apply a correction factor so longer paragraphs and shorter paragraphs get treated equally
                             smooth_idf=True #Adds 1 to all document frequencies, as if an extra document existed that used every word once.  Prevents divide-by-zero errors
                            )


#Applying the vectorizer
emma_paras_tfidf=vectorizer.fit_transform(emma_paras)
print("Number of features: %d" % emma_paras_tfidf.get_shape()[1])
# Out:
# Number of features: 1948

# %%
#splitting into training and test sets
X_train_tfidf, X_test_tfidf= train_test_split(emma_paras_tfidf, test_size=0.4, random_state=0)

#Reshapes the vectorizer output into something people can read
X_train_tfidf_csr = X_train_tfidf.tocsr()

#number of paragraphs
n = X_train_tfidf_csr.shape[0]
#A list of dictionaries, one per paragraph
tfidf_bypara = [{} for _ in range(0,n)]
#List of features
terms = vectorizer.get_feature_names()
#for each paragraph, lists the feature words and their tf-idf scores
for i, j in zip(*X_train_tfidf_csr.nonzero()):
    tfidf_bypara[i][terms[j]] = X_train_tfidf_csr[i, j ]

#Keep in mind that the log base 2 of 1 is 0, so a tf-idf score of 0 indicates that the word was present once in that sentence.
print('Original sentence:', X_train[9])
print('Tf_idf vector:', tfidf_bypara[9])
# Out:
# Original sentence: " There appeared such a perfectly good understanding among them all " he began rather quickly , but checking himself , added , " however , it is impossible for me to say on what terms they really were  how it might all be behind the scenes .
# Tf_idf vector: {'quickly': 7.3851943989977258, 'appeared': 6.0634385590154061, 'impossible': 6.1324314305023577, 'perfectly': 5.8270497809511754, 'added': 5.8811170022214512, 'terms': 7.1620508476835161, 'understanding': 6.1324314305023577, 'good': 4.2176118685170749, 'began': 5.4756518941132866, 'say': 4.2388892669643603, 'really': 4.9213411584075573}

# %%
#Our SVD data reducer.  We are going to reduce the feature space from 1379 to 130.
svd= TruncatedSVD(130)
lsa = make_pipeline(svd, Normalizer(copy=False))
# Run SVD on the training data, then project the training data.
X_train_lsa = lsa.fit_transform(X_train_tfidf)

variance_explained=svd.explained_variance_ratio_
total_variance = variance_explained.sum()
print("Percent variance captured by all components:",total_variance*100)

#Looking at what sorts of paragraphs our solution considers similar, for the first five identified topics
paras_by_component=pd.DataFrame(X_train_lsa,index=X_train)
for i in range(5):
    print('Component {}:'.format(i))
    print(paras_by_component.loc[:,i].sort_values(ascending=False)[0:10])
# Out:
# Percent variance captured by all components: 47.9970767757
# Component 0:
# " I do not know what your opinion may be , Mrs . Weston ," said Mr . Knightley , " of this great intimacy between Emma and Harriet Smith , but I think it a bad thing ."    0.529928
# " You are right , Mrs . Weston ," said Mr . Knightley warmly , " Miss Fairfax is as capable as any of us of forming a just opinion of Mrs . Elton .                         0.526824
# " In one respect , perhaps , Mr . Elton ' s manners are superior to Mr . Knightley ' s or Mr . Weston ' s .                                                                 0.505335
# " You have made her too tall , Emma ," said Mr . Knightley .                                                                                                                0.488342
# " You get upon delicate subjects , Emma ," said Mrs . Weston smiling ; " remember that I am here . Mr .                                                                     0.476461
# " Emma ," said Mr . Knightley presently , " I have a piece of news for you .                                                                                                0.468785
# Emma knew that she had , but would not own it ; and Mr . Elton warmly added ,                                                                                               0.468336
# "` Mr .                                                                                                                                                                     0.462037
# Emma was most agreeably surprized . Mr .                                                                                                                                    0.456604
# Mr . Knightley had done all in his power for Mr . Woodhouse ' s entertainment .                                                                                             0.453366
# Name: 0, dtype: float64
# Component 1:
# " But Miss Bates and Miss Fairfax !"                                                                                                                                              0.722097
# To Miss                                                                                                                                                                           0.695062
# " You and Miss Smith , and Miss Fairfax , will be three , and the two Miss Coxes five ," had been repeated many times over .                                                      0.651335
# Miss Bates and Miss Fairfax , escorted by the two gentlemen , walked into the room ; and Mrs . Elton seemed to think it as much her duty as Mrs . Weston ' s to receive them .    0.567391
# " You seem to me to have forgotten Mrs . and Miss Bates ," said Emma , " I have not heard one inquiry after them ."                                                               0.561546
# For Miss , read Miss Smith .                                                                                                                                                      0.560180
# " Such attentions as Mrs . Elton ' s , I should have imagined , would rather disgust than gratify Miss Fairfax .                                                                  0.548334
# They were just approaching the house where lived Mrs . and Miss Bates .                                                                                                           0.544839
# Miss Bates looked about her , so happily !                                                                                                                                        0.532858
# " And when is Miss Fairfax to leave you ?"                                                                                                                                        0.527968
# Name: 1, dtype: float64
# Component 2:
# Mr . Woodhouse was resigned .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.628999
# There was no recovering Miss Taylor  nor much likelihood of ceasing to pity her ; but a few weeks brought some alleviation to Mr . Woodhouse .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.558318
# Mr . Knightley had done all in his power for Mr . Woodhouse ' s entertainment .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       0.527602
# "` Mr .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.523117
# " What can it be , Miss Woodhouse ? what can it be ?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.513464
# The evening of the very day on which they went brought a note from Mr . Elton to Mr . Woodhouse , a long , civil , ceremonious note , to say , with Mr . Elton ' s best compliments , " that he was proposing to leave Highbury the following morning in his way to Bath ; where , in compliance with the pressing entreaties of some friends , he had engaged to spend a few weeks , and very much regretted the impossibility he was under , from various circumstances of weather and business , of taking a personal leave of Mr . Woodhouse , of whose friendly civilities he should ever retain a grateful sense  and had Mr . Woodhouse any commands , should be happy to attend to them ."    0.508214
# Mr . Woodhouse at last was off ; but Mr . Knightley , instead of being immediately off likewise , sat down again , seemingly inclined for more chat .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.489877
# " He is very young to settle ," was Mr . Woodhouse ' s observation .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.487433
# Mr . Woodhouse agreed to it all , but added ,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.481144
# " A new neighbour for us all , Miss Woodhouse !"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.459256
# Name: 2, dtype: float64
# Component 3:
# Mrs . Elton turned to Mrs . Weston .                                                       0.606318
# [ To Mrs .                                                                                 0.590959
# " Well done , Mrs .                                                                        0.590959
# Mrs . Weston was disappointed .                                                            0.580411
# " How do you do , Mrs . Ford ?                                                             0.566598
# " I suspect they do not satisfy Mrs . Weston .                                             0.550658
# Such a conclusion could not pass unanswered by Mrs . Weston .                              0.527139
# " It appears to me a plan that nobody can object to , if Mr . and Mrs . Weston do not .    0.523380
# Mrs . Bates and Mrs . Elton were together .                                                0.514664
# Mrs . Elton was very much disappointed .                                                   0.497841
# Name: 3, dtype: float64
# Component 4:
# Their first pause was at the Crown Inn , an inconsiderable house , though the principal one of the sort , where a couple of pair of post - horses were kept , more for the convenience of the neighbourhood than from any run on the road ; and his companions had not expected to be detained by any interest excited there ; but in passing it they gave the history of the large room visibly added ; it had been built many years ago for a ball - room , and while the neighbourhood had been in a particularly populous , dancing state , had been occasionally used as such ; but such brilliant days had long passed away , and now the highest purpose for which it was ever wanted was to accommodate a whist club established among the gentlemen and half - gentlemen of the place .                                                                                                                                                                                                                                                         0.559229
# The charming Augusta Hawkins , in addition to all the usual advantages of perfect beauty and merit , was in possession of an independent fortune , of so many thousands as would always be called ten ; a point of some dignity , as well as some convenience : the story told well ; he had not thrown himself away  he had gained a woman of 10 , 000 l . or thereabouts ; and he had gained her with such delightful rapidity  the first hour of introduction had been so very soon followed by distinguishing notice ; the history which he had to give Mrs . Cole of the rise and progress of the affair was so glorious  the steps so quick , from the accidental rencontre , to the dinner at Mr . Green ' s , and the party at Mrs . Brown ' s  smiles and blushes rising in importance  with consciousness and agitation richly scattered  the lady had been so easily impressed  so sweetly disposed  had in short , to use a most intelligible phrase , been so very ready to have him , that vanity and prudence were equally contented .    0.555676
# After this , he made some progress without any pause .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.433426
# Harriet could not very soon give an intelligible account .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.287307
# Harriet could not long resist so delightful a persuasion .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.259332
# In half a minute they were in the room .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.250867
# " Six years hence !                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.249255
# " It is a very simple story .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            0.246258
# " No , no ; your room is full enough .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.237130
# " The Crown !"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           0.230531
# Name: 4, dtype: float64

# %% [markdown]
# #### 2. Change max_df to 0.1<BR/>
# max_df = 0.1 means that we drop words that occur in more than 10% of paragraphs. Setting df at 0.2 or higher did not seem to make much difference to the results.<BR/><BR/>
# This resulted in changes to Components 1 and 4, which now consist of phrases that are different but similar to their analogues in the base case (max_df = 0.5). Components 0, 2 and 3 remain unchanged which is logical when you note that they consist of mostly a single, relatively uncommon, word ('Oh', 'CHAPTER' and 'Ah' respectively).

# %%
vectorizer = TfidfVectorizer(max_df=0.1, # drop words that occur in more than 20% of the paragraphs
                             min_df=2, # only use words that appear at least twice
                             stop_words='english', 
                             lowercase=True, #convert everything to lower case (since Alice in Wonderland has the HABIT of CAPITALIZING WORDS for EMPHASIS)
                             use_idf=True,#we definitely want to use inverse document frequencies in our weighting
                             norm=u'l2', #Applies a correction factor so that longer paragraphs and shorter paragraphs get treated equally
                             smooth_idf=True #Adds 1 to all document frequencies, as if an extra document existed that used every word once.  Prevents divide-by-zero errors
                            )


#Applying the vectorizer
emma_paras_tfidf=vectorizer.fit_transform(emma_paras)
print("Number of features: %d" % emma_paras_tfidf.get_shape()[1])
# Out:
# Number of features: 1945

# %%
#splitting into training and test sets
X_train_tfidf, X_test_tfidf= train_test_split(emma_paras_tfidf, test_size=0.4, random_state=0)

#Reshapes the vectorizer output into something people can read
X_train_tfidf_csr = X_train_tfidf.tocsr()

#number of paragraphs
n = X_train_tfidf_csr.shape[0]
#A list of dictionaries, one per paragraph
tfidf_bypara = [{} for _ in range(0,n)]
#List of features
terms = vectorizer.get_feature_names()
#for each paragraph, lists the feature words and their tf-idf scores
for i, j in zip(*X_train_tfidf_csr.nonzero()):
    tfidf_bypara[i][terms[j]] = X_train_tfidf_csr[i, j ]

#Keep in mind that the log base 2 of 1 is 0, so a tf-idf score of 0 indicates that the word was present once in that sentence.
print('Original sentence:', X_train[9])
print('Tf_idf vector:', tfidf_bypara[9])
# Out:
# Original sentence: " There appeared such a perfectly good understanding among them all " he began rather quickly , but checking himself , added , " however , it is impossible for me to say on what terms they really were  how it might all be behind the scenes .
# Tf_idf vector: {'quickly': 0.38070256670926012, 'appeared': 0.31256680566382117, 'impossible': 0.31612334890976324, 'perfectly': 0.30038109873611568, 'added': 0.30316823321090014, 'terms': 0.36919964367970953, 'understanding': 0.31612334890976324, 'good': 0.2174154906397317, 'began': 0.28226673772842847, 'say': 0.21851232841598259, 'really': 0.25369233488450216}

# %%
#Our SVD data reducer.  We are going to reduce the feature space from 1379 to 130.
svd= TruncatedSVD(130)
lsa = make_pipeline(svd, Normalizer(copy=False))
# Run SVD on the training data, then project the training data.
X_train_lsa = lsa.fit_transform(X_train_tfidf)

variance_explained=svd.explained_variance_ratio_
total_variance = variance_explained.sum()
print("Percent variance captured by all components:",total_variance*100)

#Looking at what sorts of paragraphs our solution considers similar, for the first five identified topics
paras_by_component=pd.DataFrame(X_train_lsa,index=X_train)
for i in range(5):
    print('Component {}:'.format(i))
    print(paras_by_component.loc[:,i].sort_values(ascending=False)[0:10])
# Out:
# Percent variance captured by all components: 44.2762000554
# Component 0:
# " Oh !     0.999307
# " Oh !     0.999307
# " Oh !     0.999307
# " Oh !     0.999307
# " Oh !     0.999307
# " Oh !"    0.999307
# " Oh !     0.999307
# " Oh !"    0.999307
# " Oh !     0.999307
# " Oh !     0.999307
# Name: 0, dtype: float64
# Component 1:
# Miss Bates and Miss Fairfax , escorted by the two gentlemen , walked into the room ; and Mrs . Elton seemed to think it as much her duty as Mrs . Weston ' s to receive them .                                                                                                                                                                                                                                           0.662046
# " Such attentions as Mrs . Elton ' s , I should have imagined , would rather disgust than gratify Miss Fairfax .                                                                                                                                                                                                                                                                                                         0.636604
# " You are right , Mrs . Weston ," said Mr . Knightley warmly , " Miss Fairfax is as capable as any of us of forming a just opinion of Mrs . Elton .                                                                                                                                                                                                                                                                      0.622173
# Mrs . Elton turned to Mrs . Weston .                                                                                                                                                                                                                                                                                                                                                                                     0.597350
# Mrs . Bates and Mrs . Elton were together .                                                                                                                                                                                                                                                                                                                                                                              0.578877
# " Another thing must be taken into consideration too  Mrs . Elton does not talk _to_ Miss Fairfax as she speaks _of_ her .                                                                                                                                                                                                                                                                                               0.570396
# Frank Churchill returned to his station by Emma ; and as soon as Miss Bates was quiet , she found herself necessarily overhearing the discourse of Mrs . Elton and Miss Fairfax , who were standing a little way behind her . He was thoughtful .                                                                                                                                                                        0.560202
# " Mrs . Elton , I suppose , has been the person to whom Miss Fairfax owes "                                                                                                                                                                                                                                                                                                                                              0.553996
# Mr . Weston had accompanied her to Mrs . Bates ' s , and gone through his share of this essential attention most handsomely ; but she having then induced Miss Fairfax to join her in an airing , was now returned with much more to say , and much more to say with satisfaction , than a quarter of an hour spent in Mrs . Bates ' s parlour , with all the encumbrance of awkward feelings , could have afforded .    0.533772
# " So do I ," said Mrs . Weston gently , " very much ."                                                                                                                                                                                                                                                                                                                                                                   0.532196
# Name: 1, dtype: float64
# Component 2:
# CHAPTER V       0.998928
# CHAPTER X       0.998928
# CHAPTER X       0.998928
# CHAPTER X       0.998928
# CHAPTER I       0.998928
# CHAPTER V       0.998928
# CHAPTER I       0.998928
# CHAPTER V       0.998928
# CHAPTER I       0.998928
# CHAPTER XVII    0.998103
# Name: 2, dtype: float64
# Component 3:
# " Ah !      0.996364
# " Ah !      0.996364
# " Ah !      0.996364
# " Ah !      0.996364
# " Ah !      0.996364
# " Ah !      0.996364
# But ah !    0.996364
# " Ah !      0.996364
# " Ah !      0.996364
# " Ah !      0.996364
# Name: 3, dtype: float64
# Component 4:
# " Dear Miss Woodhouse !"                                                                                                                                 0.655639
# Emma had not to listen to such paradings again  to any so exclusively addressed to herself  so disgustingly decorated with a " dear Miss Woodhouse ."    0.630474
# " Thank you , dear Miss Woodhouse .                                                                                                                      0.547760
# When Harriet had closed her evidence , she appealed to her dear Miss Woodhouse , to say whether she had not good ground for hope .                       0.489400
# To Miss                                                                                                                                                  0.479401
# " What can it be , Miss Woodhouse ? what can it be ?                                                                                                     0.472106
# " Dear me !                                                                                                                                              0.465385
# " Emma , my dear Emma "                                                                                                                                  0.465385
# " Dear me !                                                                                                                                              0.465385
# " What is to be done , my dear Emma ? what is to be done ?"                                                                                              0.465385
# Name: 4, dtype: float64

# %% [markdown]
# #### 3. Change the Regularization Coefficient to l1<BR/>
# Changing the regularization coefficient to l1 has not made much change to the 'Oh', 'Ah' and 'CHAPTER' components. Component 3 contains several references to Emma (with higher tf-idf scores than when Norm=u'l2', while Component 4 contains several uses of the words 'Thank you' with high tf-idf scores. This component is the only one that does not appear among the top 5 components when l2 regularization is used.

# %%
vectorizer = TfidfVectorizer(max_df=0.5, # drop words that occur in more than half of the paragraphs
                             min_df=2, # only use words that appear at least twice
                             stop_words='english', 
                             lowercase=True, #convert everything to lower case (since Alice in Wonderland has the HABIT of CAPITALIZING WORDS for EMPHASIS)
                             use_idf=True,#we definitely want to use inverse document frequencies in our weighting
                             norm=u'l1', #Applies a correction factor so that longer paragraphs and shorter paragraphs get treated equally
                             smooth_idf=True #Adds 1 to all document frequencies, as if an extra document existed that used every word once.  Prevents divide-by-zero errors
                            )


#Applying the vectorizer
emma_paras_tfidf=vectorizer.fit_transform(emma_paras)
print("Number of features: %d" % emma_paras_tfidf.get_shape()[1])
# Out:
# Number of features: 1948

# %%
#splitting into training and test sets
X_train_tfidf, X_test_tfidf= train_test_split(emma_paras_tfidf, test_size=0.4, random_state=0)

#Reshapes the vectorizer output into something people can read
X_train_tfidf_csr = X_train_tfidf.tocsr()

#number of paragraphs
n = X_train_tfidf_csr.shape[0]
#A list of dictionaries, one per paragraph
tfidf_bypara = [{} for _ in range(0,n)]
#List of features
terms = vectorizer.get_feature_names()
#for each paragraph, lists the feature words and their tf-idf scores
for i, j in zip(*X_train_tfidf_csr.nonzero()):
    tfidf_bypara[i][terms[j]] = X_train_tfidf_csr[i, j ]

#Keep in mind that the log base 2 of 1 is 0, so a tf-idf score of 0 indicates that the word was present once in that sentence.
print('Original sentence:', X_train[9])
print('Tf_idf vector:', tfidf_bypara[9])
# Out:
# Original sentence: " There appeared such a perfectly good understanding among them all " he began rather quickly , but checking himself , added , " however , it is impossible for me to say on what terms they really were  how it might all be behind the scenes .
# Tf_idf vector: {'quickly': 0.1164173940498016, 'appeared': 0.095581737986133022, 'impossible': 0.096669315356826713, 'perfectly': 0.091855395247126798, 'added': 0.092707690347801963, 'terms': 0.11289984402477532, 'understanding': 0.096669315356826713, 'good': 0.066484828471530602, 'began': 0.086316092684444623, 'say': 0.066820237283481229, 'really': 0.077578149191251389}

# %%
#Our SVD data reducer.  We are going to reduce the feature space from 1379 to 130.
svd= TruncatedSVD(20)
lsa = make_pipeline(svd, Normalizer(copy=False))
# Run SVD on the training data, then project the training data.
X_train_lsa = lsa.fit_transform(X_train_tfidf)

variance_explained=svd.explained_variance_ratio_
total_variance = variance_explained.sum()
print("Percent variance captured by all components:",total_variance*100)

#Looking at what sorts of paragraphs our solution considers similar, for the first five identified topics
paras_by_component=pd.DataFrame(X_train_lsa,index=X_train)
for i in range(5):
    print('Component {}:'.format(i))
    print(paras_by_component.loc[:,i].sort_values(ascending=False)[0:10])
# Out:
# Percent variance captured by all components: 33.1869559097
# Component 0:
# " Oh !     0.999947
# " Oh !     0.999947
# " Oh !     0.999947
# " Oh !     0.999947
# " Oh !     0.999947
# " Oh !"    0.999947
# " Oh !     0.999947
# " Oh !     0.999947
# " Oh !     0.999947
# " Oh !     0.999947
# Name: 0, dtype: float64
# Component 1:
# " Ah !      0.999994
# " Ah !      0.999994
# " Ah !      0.999994
# " Ah !      0.999994
# " Ah !"     0.999994
# " Ah !      0.999994
# " Ah !      0.999994
# " Ah !      0.999994
# " Ah !      0.999994
# But ah !    0.999994
# Name: 1, dtype: float64
# Component 2:
# CHAPTER I       1.0
# CHAPTER X       1.0
# CHAPTER V       1.0
# CHAPTER V       1.0
# CHAPTER X       1.0
# CHAPTER I       1.0
# CHAPTER V       1.0
# CHAPTER X       1.0
# CHAPTER I       1.0
# CHAPTER XVII    1.0
# Name: 2, dtype: float64
# Component 3:
# " I am afraid ," said he , composing his features , " I am very much afraid , my dear Emma , that you will not smile when you hear it ."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.856928
# " From something that he said , my dear Emma , I rather imagine "                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.841809
# Mrs . Weston was acting no part , feigning no feelings in all that she said to him in favour of the event . She had been extremely surprized , never more so , than when Emma first opened the affair to her ; but she saw in it only increase of happiness to all , and had no scruple in urging him to the utmost . She had such a regard for Mr . Knightley , as to think he deserved even her dearest Emma ; and it was in every respect so proper , suitable , and unexceptionable a connexion , and in one respect , one point of the highest importance , so peculiarly eligible , so singularly fortunate , that now it seemed as if Emma could not safely have attached herself to any other creature , and that she had herself been the stupidest of beings in not having thought of it , and wished it long ago . How very few of those men in a rank of life to address Emma would have renounced their own home for Hartfield !    0.825713
# " My dearest Emma ," said he , " for dearest you will always be , whatever the event of this hour ' s conversation , my dearest , most beloved Emma  tell me at once .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           0.825572
# Emma gave a start , which did not seem like being prepared  and her eyes , in eager gaze , said , " No , this is impossible !"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.821717
# " I am here on no business of my own ," said Emma ; " I am only waiting for my friend .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          0.819836
# " I always told you she was  a little ; but you will soon overcome all that part of her reserve which ought to be overcome , all that has its foundation in diffidence .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.818340
# " Whoever Colonel Campbell might employ ," said Frank Churchill , with a smile at Emma , " the person has not chosen ill .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       0.816255
# " As you do us such ample justice now ," said Emma , laughing , " I will venture to ask , whether you did not come a little doubtfully at first ?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.815525
# " Not quite ," returned Emma , with forced calmness , " for all that you then said , appeared to me to relate to a different person .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            0.811183
# Name: 3, dtype: float64
# Component 4:
# " Thank you .                                                                                                                                                  0.992013
# " No , not now , I thank you .                                                                                                                                 0.992013
# " No , I thank you .                                                                                                                                           0.992013
# " Thank you .                                                                                                                                                  0.992013
# " Thank you .                                                                                                                                                  0.992013
# " How d ' ye do ? how d ' ye do ? Very well , I thank you .                                                                                                    0.991725
# " Thank you , thank you , my own sweet little friend .                                                                                                         0.991064
# " I have not the least wish for it , I thank you ."                                                                                                            0.990841
# " Thank you , thank you  but on no account . I would rather walk . And for _me_ to be afraid of walking alone ! I , who may so soon have to guard others !"    0.989679
# " Thank you , but I would rather you did not mention the subject to her ; till the time draws nearer , I do not wish to be giving any body trouble ."          0.961699
# Name: 4, dtype: float64
